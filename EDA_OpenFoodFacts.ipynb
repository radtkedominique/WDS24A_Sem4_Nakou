# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset
openfoods_df = pd.read_csv('data_raw/en.openfoodfacts.org.products.tsv', sep='\t',
    on_bad_lines='skip',
    engine='python')

# %%
openfoods_df.head()
# Out:
#       code                                                url  \
# 0   3087.0  http://world-en.openfoodfacts.org/product/0000...
# 1   4530.0  http://world-en.openfoodfacts.org/product/0000...
# 2   4559.0  http://world-en.openfoodfacts.org/product/0000...
# 3  16087.0  http://world-en.openfoodfacts.org/product/0000...
# 4  16094.0  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
openfoods_df['countries_en'].value_counts()
# Out:
# countries_en
# United States          173154
# France                 123960
# Switzerland             14932
# Germany                  8470
# Spain                    5529
#                         ...
# Australia,Japan             1
# Maldives                    1
# Cook Islands,France         1
# Australia,Malaysia          1
# China,Hong Kong             1
# Name: count, Length: 779, dtype: int64

# %%
de_openfoods_df = openfoods_df[openfoods_df['countries_en'].str.contains('Germany', na=False)].copy()

# %%
de_openfoods_df.drop(columns=['countries_en'], inplace=True)

# %%
de_openfoods_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9403 entries, 223 to 355958
# Columns: 162 entries, code to water-hardness_100g
# dtypes: float64(108), str(54)
# memory usage: 11.7 MB

# %%
de_openfoods_df.head(20)
# Out:
#                code                                                url  \
# 223    2.042464e+07  http://world-en.openfoodfacts.org/product/0000...
# 241    6.910524e+07  http://world-en.openfoodfacts.org/product/0000...
# 276    2.042865e+08  http://world-en.openfoodfacts.org/product/0000...
# 277    2.042866e+08  http://world-en.openfoodfacts.org/product/0000...
# 283    2.506330e+08  http://world-en.openfoodfacts.org/product/0000...
# 306    4.609387e+08  http://world-en.openfoodfacts.org/product/0000...
# 307    4.703228e+08  http://world-en.openfoodfacts.org/product/0000...
# 309    5.010506e+08  http://world-en.openfoodfacts.org/product/0000...
# 312    5.269383e+08  http://world-en.openfoodfacts.org/product/0000...
# 369    7.903100e+08  http://world-en.openfoodfacts.org/product/0000...
# 370    7.903100e+08  http://world-en.openfoodfacts.org/product/0000...
# 519    2.042862e+09  http://world-en.openfoodfacts.org/product/0002...
# ...

# %%
de_openfoods_df['categories'].value_counts()
# Out:
# categories
# Brotaufstriche                                                                                               81
# Käse                                                                                                         72
# Joghurt                                                                                                      70
# Kekse                                                                                                        57
# Milchprodukte,Käse,Frischkäse                                                                                55
#                                                                                                              ..
# Salty snacks,Appetizers,Chips and fries,Crisps,Zwiebelringe                                                   1
# de:Nahrungsergänzungsmittel,Dietary supplements,fr:Compléments alimentaires                                   1
# ...

# %%
de_openfoods_df = de_openfoods_df.dropna(subset=['categories', 'product_name'], how='all')

# %%
de_openfoods_df
# Out:
#                 code                                                url  \
# 223     2.042464e+07  http://world-en.openfoodfacts.org/product/0000...
# 276     2.042865e+08  http://world-en.openfoodfacts.org/product/0000...
# 277     2.042866e+08  http://world-en.openfoodfacts.org/product/0000...
# 283     2.506330e+08  http://world-en.openfoodfacts.org/product/0000...
# 306     4.609387e+08  http://world-en.openfoodfacts.org/product/0000...
# ...              ...                                                ...
# 354914  9.314507e+12  http://world-en.openfoodfacts.org/product/9314...
# 354975  9.316985e+12  http://world-en.openfoodfacts.org/product/9316...
# 355591  9.422769e+07  http://world-en.openfoodfacts.org/product/9422...
# 355618  9.487272e+12  http://world-en.openfoodfacts.org/product/9487...
# 355958  9.780201e+12  http://world-en.openfoodfacts.org/product/9780...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
de_openfoods_df['categories'].value_counts()

# %% [markdown]
# ### Remove alcoholic beverages
# We're removing all products that are categorized as alcoholic beverages, as they are not included in the Destatic Dataset. This is done to ensure that our analysis is consistent and focused on the types of products that are relevant to our study.

# %%
alcohol= ["Beverages,Alcoholic beverages,Beers"
,"Beverages,Alcoholic beverages,Beers,Beers from Germany"
,"Beverages,Alcoholic beverages,Beers,Beers with fruits,Cherry beers,Flavored beers,Bières lambic"
,"Beverages,Alcoholic beverages,Beers,Belgian beers,Wheat beers"
,"Beverages,Alcoholic beverages,Beers,Bier"
,"Beverages,Alcoholic beverages,Beers,Flavored beers"
,"Beverages,Alcoholic beverages,Beers,Lagers"
,"Beverages,Alcoholic beverages,Beers,Lagers,Bières de haute fermentation"
,"Beverages,Alcoholic beverages,Beers,Lagers,fr:Bières de fermentation haute"
,"Beverages,Alcoholic beverages,Beers,Organic beers,Bières au chanvre"
,"Beverages,Alcoholic beverages,Beers,Red beers"
,"Beverages,Alcoholic beverages,Hard liquors,fr:Eaux-de-vie,Whisky"
,"Beverages,Alcoholic beverages,Wines,French wines,Red wines"
,"Beverages,Alcoholic beverages,Wines,Red wines"
,"Beverages,Alcoholic beverages,Wines,Red wines,Chianti"
,"Beverages,Alcoholic beverages,Wines,Red wines,it:Montepulciano d'abruzzo"
,"Beverages,Alcoholic beverages,Wines,White wines,Wines from Italy"
,"Beverages,Alcoholic beverages,Wines,Wines from Austria,de:Niederösterreich"
,"Beers"
,"Beers from Germany"
,"Beers from Germany,Craft beers,Lagers"
,"Beers from Germany,Lagers"
,"Beers from Germany,Organic beers"
,"Beers from Germany,Weissbier"
,"Beers from Stralsund"
,"Bier"
,"Biere"
,"Biere,Beers from Germany,Stout"
,"Bieren,Alcoholvrije bieren"
,"Biermischgetränk"
,"Biermischgetränk,Biere"
,"Biermischgetränke"
,"Bières blondes"
,"Bières,Bières fortes,Boissons,Boissons alcoolisées"
,"Boissons,Boissons alcoolisées,Alcools forts,Eaux-de-vie,Whiskys,Whisky écossais"
,"Boissons,Boissons alcoolisées,Bières,Bieres aromatisées aux fruits,Bières françaises,Bières ambrées,Bières à la chataigne,Bières corses"
,"Boissons,Boissons alcoolisées,Bières,Bières blondes"
,"Boissons,Boissons alcoolisées,Bières,Bières blondes,Bières belges"
,"Boissons,Boissons alcoolisées,Bières,Bières blondes,Bières fortes"
,"Boissons,Boissons alcoolisées,Bières,Pilsener"
,"Boissons,Boissons alcoolisées,Liqueurs"
,"Boissons,Boissons alcoolisées,Vins,Vins effervescents,Vins mousseux"
,"Craft beers,Strong beers"
,"Getränke,Alcoholic beverages,Bier"
,"Getränke,Alkoholische Getränke"
,"Getränke,Alkoholische Getränke,Biere"
,"Getränke,Alkoholische Getränke,Biere,Alkoholfreie Getränke,Beers from Germany,Bayerische Biere,Alkoholfreie Weizenbiere"
,"Getränke,Alkoholische Getränke,Biere,Artisan products,Artisanal spirits,Craft beers"
,"Getränke,Alkoholische Getränke,Biere,Artisan products,Artisanal spirits,Craft beers,Obergäriges Bier"
,"Getränke,Alkoholische Getränke,Biere,Beers from Germany"
,"Getränke,Alkoholische Getränke,Biere,Beers from Germany,Bayerische Biere"
,"Getränke,Alkoholische Getränke,Biere,Beers from Germany,Bayerische Biere,Strong beers,Weissbier"
,"Getränke,Alkoholische Getränke,Biere,Beers from Germany,Lagers"
,"Getränke,Alkoholische Getränke,Biere,Beers from Germany,Weissbier"
,"Getränke,Alkoholische Getränke,Biere,Pilsner"
,"Getränke,Alkoholische Getränke,Biere,Strong beers"
,"Getränke,Alkoholische Getränke,Biere,Strong beers,Beers from Germany"
,"Getränke,Alkoholische Getränke,Biere,Ungezuckerte Getränke"
,"Getränke,Alkoholische Getränke,Biere,Weissbier"
,"Getränke,Alkoholische Getränke,Biere,Weissbier,Beers from Germany"
,"Getränke,Alkoholische Getränke,Hard liquors"
,"Getränke,Alkoholische Getränke,Hard liquors,Eaux-de-vie,Brandys,Eaux-de-vie"
,"Getränke,Alkoholische Getränke,Hard liquors,fr:Eaux-de-vie"
,"Getränke,Alkoholische Getränke,Liqueurs"
,"Getränke,Alkoholische Getränke,Liqueurs,fr:Liqueur au whisky"
,"Getränke,Alkoholische Getränke,Schnäpse,Gins"
,"Getränke,Alkoholische Getränke,Schnäpse,Liqueurs"
,"Getränke,Alkoholische Getränke,Weine"
,"Getränke,Alkoholische Getränke,Weine,Bordeauxweine"
,"Getränke,Alkoholische Getränke,Weine,Federweißer"
,"Getränke,Alkoholische Getränke,Weine,Französische Weine,Roteweine,Pomerol"
,"Getränke,Alkoholische Getränke,Weine,Französische Weine,Weißwein"
,"Getränke,Alkoholische Getränke,Weine,Roteweine"
,"Getränke,Alkoholische Getränke,Weine,Roteweine,Italienische Weine"
,"Getränke,Alkoholische Getränke,Weine,Roteweine,Spanische Weine"
,"Getränke,Alkoholische Getränke,Weine,Roteweine,Wein"
,"Getränke,Alkoholische Getränke,Weine,Roteweine,it:Provincia di Verona"
,"Getränke,Alkoholische Getränke,Weine,Schaumweine"
,"Getränke,Alkoholische Getränke,Weine,Spanische Weine"
,"Getränke,Alkoholische Getränke,Weine,Weißwein,Wines from Germany,Württemberg"
,"Getränke,Alkoholische Getränke,Weine,Wines from Germany"
,"Liqueurs"
,"Liqueurs,Tequilas"
,"Organic beers,Beers from Germany"
,"Roteweine"
,"Roteweine,Italienische Weine"
,"Roteweine,Italienische Weine,it:Veneto"
,"Roteweine,Rheinhessen"
,"Roteweine,Spanische Weine"
,"Rum"
,"Rums"
,"Scottish Whisky"
,"Sekt"
,"Vollbier,Craft Beer"
,"Weine"
,"Weine,Rotwein"
,"Weine,Weißwein"
,"Weizenbiere"
,"Weißwein"
,"Weißwein,Baden"
,"Weißwein,Wines from Germany"
,"Wheat beers"
,"Wodkas"
,"en:Beers"
,"en:Rums"
,"es:Rotwein"
,"es:Vino Rasgón de la Tierra de Castilla,es:Vino de la Tierra de Castilla,en:Wine"
,"fr:Bières avec des fruits"
,"fr:vin"
,"fr:vin blanc"
,"japanese beer"
,"red wine,Wine from Macedonia"
,"weine"
,"甜類零食"
,"Alkoholfreie Biere"
,"Alkoholfreies Bier"
,"Alkoholische Getränke"
]

# %%
de_openfoods_df = de_openfoods_df[~de_openfoods_df['categories'].isin(alcohol)]

# %%
de_openfoods_df['categories'].value_counts()
# Out:
# categories
# Brotaufstriche                                                                                               81
# Käse                                                                                                         72
# Joghurt                                                                                                      70
# Kekse                                                                                                        57
# Milchprodukte,Käse,Frischkäse                                                                                55
#                                                                                                              ..
# Salty snacks,Appetizers,Chips and fries,Crisps,Zwiebelringe                                                   1
# de:Nahrungsergänzungsmittel,Dietary supplements,fr:Compléments alimentaires                                   1
# ...
